# %%
import json
import tensorflow as tf
import numpy as np
import pandas as pd
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import nltk
from nltk.corpus import stopwords
import string

# %%
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\KIIT\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
df = pd.read_json("Sarcasm_Headlines_Dataset.json",lines = True)
df.head(10)
# Out:
#                                         article_link  \
# 0  https://www.huffingtonpost.com/entry/versace-b...
# 1  https://www.huffingtonpost.com/entry/roseanne-...
# 2  https://local.theonion.com/mom-starting-to-fea...
# 3  https://politics.theonion.com/boehner-just-wan...
# 4  https://www.huffingtonpost.com/entry/jk-rowlin...
# 5  https://www.huffingtonpost.com/entry/advancing...
# 6  https://www.huffingtonpost.com/entry/how-meat-...
# 7  https://www.huffingtonpost.com/entry/boxed-col...
# 8  https://politics.theonion.com/top-snake-handle...
# 9  https://www.huffingtonpost.com/entry/fridays-m...
#
#                                             headline  is_sarcastic
# 0  former versace store clerk sues over secret 'b...             0
# 1  the 'roseanne' revival catches up to our thorn...             0
# 2  mom starting to fear son's web series closest ...             1
# 3  boehner just wants wife to listen, not come up...             1
# 4  j.k. rowling wishes snape happy birthday in th...             0
# 5                        advancing the world's women             0
# 6     the fascinating case for eating lab-grown meat             0
# 7  this ceo will send your kids to school, if you...             0
# 8  top snake handler leaves sinking huckabee camp...             1
# 9  friday's morning email: inside trump's presser...             0

# %%
df.head(-100) # last 100 datas will be deducted
# Out:
#                                             article_link  \
# 0      https://www.huffingtonpost.com/entry/versace-b...
# 1      https://www.huffingtonpost.com/entry/roseanne-...
# 2      https://local.theonion.com/mom-starting-to-fea...
# 3      https://politics.theonion.com/boehner-just-wan...
# 4      https://www.huffingtonpost.com/entry/jk-rowlin...
# ...                                                  ...
# 26604  https://www.huffingtonpost.com/entry/roger-ail...
# 26605  https://www.huffingtonpost.com/entry/laquan-mc...
# 26606  https://entertainment.theonion.com/tv-viewers-...
# 26607  https://www.huffingtonpost.com/entry/apostolos...
# 26608  https://www.theonion.com/area-man-realizes-hes...
#
#                                                 headline  is_sarcastic
# 0      former versace store clerk sues over secret 'b...             0
# 1      the 'roseanne' revival catches up to our thorn...             0
# 2      mom starting to fear son's web series closest ...             1
# 3      boehner just wants wife to listen, not come up...             1
# 4      j.k. rowling wishes snape happy birthday in th...             0
# ...                                                  ...           ...
# 26604  roger ailes hires lawyer for possible lawsuit ...             0
# 26605  police have no idea how laquan mcdonald footag...             0
# 26606  tv viewers outraged at timing of commercial break             1
# 26607  greek and turkish cypriots find common ground ...             0
# 26608          area man realizes he's not the cool uncle             1
#
# [26609 rows x 3 columns]

# %%
df.tail()
# Out:
#                                             article_link  \
# 26704  https://www.huffingtonpost.com/entry/american-...
# 26705  https://www.huffingtonpost.com/entry/americas-...
# 26706  https://www.huffingtonpost.com/entry/reparatio...
# 26707  https://www.huffingtonpost.com/entry/israeli-b...
# 26708  https://www.huffingtonpost.com/entry/gourmet-g...
#
#                                                 headline  is_sarcastic
# 26704               american politics in moral free-fall             0
# 26705                            america's best 20 hikes             0
# 26706                              reparations and obama             0
# 26707  israeli ban targeting boycott supporters raise...             0
# 26708                  gourmet gifts for the foodie 2014             0

# %%
df.drop(['article_link'],axis = 1)
# Out:
#                                                 headline  is_sarcastic
# 0      former versace store clerk sues over secret 'b...             0
# 1      the 'roseanne' revival catches up to our thorn...             0
# 2      mom starting to fear son's web series closest ...             1
# 3      boehner just wants wife to listen, not come up...             1
# 4      j.k. rowling wishes snape happy birthday in th...             0
# ...                                                  ...           ...
# 26704               american politics in moral free-fall             0
# 26705                            america's best 20 hikes             0
# 26706                              reparations and obama             0
# 26707  israeli ban targeting boycott supporters raise...             0
# 26708                  gourmet gifts for the foodie 2014             0
#
# [26709 rows x 2 columns]

# %%
label = df['is_sarcastic'].tolist()

# %%
sentence[0:10]
# Out:
# ["former versace store clerk sues over secret 'black code' for minority shoppers",
#  "the 'roseanne' revival catches up to our thorny political mood, for better and worse",
#  "mom starting to fear son's web series closest thing she will have to grandchild",
#  'boehner just wants wife to listen, not come up with alternative debt-reduction ideas',
#  'j.k. rowling wishes snape happy birthday in the most magical way',
#  "advancing the world's women",
#  'the fascinating case for eating lab-grown meat',
#  'this ceo will send your kids to school, if you work for his company',
#  'top snake handler leaves sinking huckabee campaign',
#  "friday's morning email: inside trump's presser for the ages"]

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\KIIT\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
stop_words = set(stopwords.words("english"))

# Function to remove stopwords from a single sentence
def remove_stopwords(sentence):
    words = nltk.word_tokenize(sentence)
    filtered_words = [word for word in words if word.lower() not in stop_words]
    return " ".join(filtered_words)

# Remove stopwords from each sentence in the list
sentence = [remove_stopwords(sentence) for sentence in sentence]

# print the sentences without stopwords
sentence[:10]
# Out:
# ["former versace store clerk sues secret 'black code ' minority shoppers",
#  "'roseanne ' revival catches thorny political mood , better worse",
#  "mom starting fear son 's web series closest thing grandchild",
#  'boehner wants wife listen , come alternative debt-reduction ideas',
#  'j.k. rowling wishes snape happy birthday magical way',
#  "advancing world 's women",
#  'fascinating case eating lab-grown meat',
#  'ceo send kids school , work company',
#  'top snake handler leaves sinking huckabee campaign',
#  "friday 's morning email : inside trump 's presser ages"]

# %%
train_size = round(len(sentence)*0.75)
train_sen = sentence[0:train_size]
test_sen = sentence[train_size:]
train_label = label[0:train_size]
test_label = label[train_size:]

# %%
vocab_size = 10000
oov_tok = "oov"

# %%
tokenizer = Tokenizer(num_words = vocab_size,oov_token = oov_tok)
tokenizer.fit_on_texts(train_sen)
word_index = tokenizer.word_index

# %%
(word_index)
# Out:
# {'oov': 1,
#  "'s": 2,
#  "'": 3,
#  'trump': 4,
#  'new': 5,
#  'man': 6,
#  "n't": 7,
#  'year': 8,
#  'one': 9,
#  'report': 10,
#  'area': 11,
#  'woman': 12,
#  'u': 13,
#  'day': 14,
#  'donald': 15,
#  'says': 16,
#  'time': 17,
#  's': 18,
#  'first': 19,
#  'obama': 20,
#  'women': 21,
#  'like': 22,
#  'old': 23,
#  'get': 24,
#  'world': 25,
#  'people': 26,
#  'life': 27,
#  'nation': 28,
#  'clinton': 29,
#  'house': 30,
#  'back': 31,
#  'white': 32,
#  'could': 33,
#  'still': 34,
#  'make': 35,
#  '5': 36,
#  'americans': 37,
#  'way': 38,
#  'family': 39,
#  'gop': 40,
#  'study': 41,
#  'president': 42,
#  'black': 43,
#  'show': 44,
#  'would': 45,
#  'best': 46,
#  'school': 47,
#  'bill': 48,
#  'years': 49,
#  '3': 50,
#  'police': 51,
#  'america': 52,
#  'know': 53,
#  'hillary': 54,
#  'watch': 55,
#  'last': 56,
#  'really': 57,
#  '10': 58,
#  'things': 59,
#  'video': 60,
#  'ca': 61,
#  'going': 62,
#  'death': 63,
#  'good': 64,
#  'state': 65,
#  'american': 66,
#  'finds': 67,
#  'mom': 68,
#  'home': 69,
#  'love': 70,
#  'may': 71,
#  'need': 72,
#  'child': 73,
#  'health': 74,
#  'say': 75,
#  '2': 76,
#  'right': 77,
#  'every': 78,
#  'work': 79,
#  'campaign': 80,
#  '000': 81,
#  'parents': 82,
#  'take': 83,
#  'gets': 84,
#  "'the": 85,
#  'dead': 86,
#  'little': 87,
#  'court': 88,
#  'party': 89,
#  'kids': 90,
#  'high': 91,
#  'getting': 92,
#  'john': 93,
#  '7': 94,
#  'go': 95,
#  'calls': 96,
#  "'re": 97,
#  'takes': 98,
#  'guy': 99,
#  'makes': 100,
#  'big': 101,
#  'election': 102,
#  'news': 103,
#  'local': 104,
#  'real': 105,
#  'never': 106,
#  'see': 107,
#  '4': 108,
#  'college': 109,
#  'plan': 110,
#  'self': 111,
#  '6': 112,
#  'dad': 113,
#  'want': 114,
#  'stop': 115,
#  'week': 116,
#  'bush': 117,
#  'office': 118,
#  'change': 119,
#  'look': 120,
#  'sex': 121,
#  'gay': 122,
#  'war': 123,
#  'baby': 124,
#  'two': 125,
#  'next': 126,
#  'around': 127,
#  'another': 128,
#  'even': 129,
#  'got': 130,
#  '1': 131,
#  'wants': 132,
#  'dog': 133,
#  'children': 134,
#  'thing': 135,
#  'million': 136,
#  'north': 137,
#  'congress': 138,
#  'long': 139,
#  'job': 140,
#  'gun': 141,
#  'us': 142,
#  'much': 143,
#  'ever': 144,
#  'made': 145,
#  'actually': 146,
#  'care': 147,
#  'students': 148,
#  'help': 149,
#  'live': 150,
#  'couple': 151,
#  'son': 152,
#  'city': 153,
#  'national': 154,
#  'ways': 155,
#  '20': 156,
#  'finally': 157,
#  'friend': 158,
#  'debate': 159,
#  'night': 160,
#  'game': 161,
#  'god': 162,
#  'men': 163,
#  'season': 164,
#  '9': 165,
#  'shows': 166,
#  'sexual': 167,
#  'better': 168,
#  'give': 169,
#  'everyone': 170,
#  'star': 171,
#  'wo': 172,
#  'senate': 173,
#  'tv': 174,
#  'free': 175,
#  'history': 176,
#  'media': 177,
#  'making': 178,
#  'climate': 179,
#  'story': 180,
#  'money': 181,
#  'shooting': 182,
#  'without': 183,
#  'anti': 184,
#  'teen': 185,
#  'law': 186,
#  'away': 187,
#  'face': 188,
#  'end': 189,
#  'government': 190,
#  '8': 191,
#  'entire': 192,
#  'paul': 193,
#  'trying': 194,
#  'let': 195,
#  'found': 196,
#  'announces': 197,
#  'top': 198,
#  'film': 199,
#  'girl': 200,
#  'supreme': 201,
#  'business': 202,
#  'come': 203,
#  'company': 204,
#  "'ll": 205,
#  'york': 206,
#  'tell': 207,
#  'food': 208,
#  'bad': 209,
#  'pope': 210,
#  'mother': 211,
#  'part': 212,
#  'deal': 213,
#  'reveals': 214,
#  'power': 215,
#  'car': 216,
#  'sanders': 217,
#  'facebook': 218,
#  'body': 219,
#  'attack': 220,
#  'james': 221,
#  'introduces': 222,
#  'think': 223,
#  'find': 224,
#  'movie': 225,
#  'father': 226,
#  'friends': 227,
#  'fight': 228,
#  '11': 229,
#  'enough': 230,
#  'fire': 231,
#  'morning': 232,
#  'middle': 233,
#  'book': 234,
#  'wedding': 235,
#  'run': 236,
#  'call': 237,
#  'used': 238,
#  'line': 239,
#  'public': 240,
#  'use': 241,
#  'former': 242,
#  'tax': 243,
#  'single': 244,
#  'thinks': 245,
#  'second': 246,
#  'email': 247,
#  'support': 248,
#  'rights': 249,
#  'photos': 250,
#  'republican': 251,
#  'looking': 252,
#  'great': 253,
#  'asks': 254,
#  'christmas': 255,
#  'room': 256,
#  'speech': 257,
#  'team': 258,
#  'must': 259,
#  'behind': 260,
#  'student': 261,
#  'marriage': 262,
#  'republicans': 263,
#  '2016': 264,
#  'wife': 265,
#  'claims': 266,
#  'security': 267,
#  'already': 268,
#  'vote': 269,
#  'keep': 270,
#  'judge': 271,
#  'democrats': 272,
#  'talk': 273,
#  'boy': 274,
#  "'m": 275,
#  'future': 276,
#  'presidential': 277,
#  'voters': 278,
#  'teacher': 279,
#  'california': 280,
#  'goes': 281,
#  'department': 282,
#  'violence': 283,
#  'control': 284,
#  'ban': 285,
#  'race': 286,
#  'might': 287,
#  'ad': 288,
#  'case': 289,
#  'inside': 290,
#  'fans': 291,
#  'coming': 292,
#  'open': 293,
#  'group': 294,
#  'name': 295,
#  'win': 296,
#  'human': 297,
#  'twitter': 298,
#  'country': 299,
#  'biden': 300,
#  'ryan': 301,
#  'sure': 302,
#  'perfect': 303,
#  'killed': 304,
#  'secret': 305,
#  'political': 306,
#  'full': 307,
#  'pretty': 308,
#  'music': 309,
#  '12': 310,
#  'texas': 311,
#  'three': 312,
#  'bernie': 313,
#  'obamacare': 314,
#  'record': 315,
#  'something': 316,
#  'working': 317,
#  'always': 318,
#  '15': 319,
#  'missing': 320,
#  'minutes': 321,
#  'russia': 322,
#  'word': 323,
#  'releases': 324,
#  'poll': 325,
#  'ready': 326,
#  'living': 327,
#  'super': 328,
#  'kim': 329,
#  'scientists': 330,
#  'post': 331,
#  'meet': 332,
#  'days': 333,
#  'art': 334,
#  'reports': 335,
#  'unveils': 336,
#  'save': 337,
#  'shot': 338,
#  'photo': 339,
#  'town': 340,
#  'wall': 341,
#  'person': 342,
#  'girls': 343,
#  'korea': 344,
#  'summer': 345,
#  'everything': 346,
#  'comes': 347,
#  'lives': 348,
#  'fucking': 349,
#  'month': 350,
#  'mike': 351,
#  'start': 352,
#  'china': 353,
#  'states': 354,
#  'today': 355,
#  'running': 356,
#  'drug': 357,
#  'class': 358,
#  'place': 359,
#  'up': 360,
#  'thousands': 361,
#  'gives': 362,
#  'candidate': 363,
#  'iran': 364,
#  'rock': 365,
#  'leaves': 366,
#  'water': 367,
#  'a': 368,
#  'head': 369,
#  'cancer': 370,
#  'female': 371,
#  'education': 372,
#  'age': 373,
#  'looks': 374,
#  'social': 375,
#  'many': 376,
#  'put': 377,
#  'breaking': 378,
#  'daughter': 379,
#  'air': 380,
#  'hollywood': 381,
#  'employee': 382,
#  'left': 383,
#  'plans': 384,
#  'forced': 385,
#  'heart': 386,
#  'cruz': 387,
#  'earth': 388,
#  'times': 389,
#  'hard': 390,
#  'dream': 391,
#  'tells': 392,
#  'fan': 393,
#  'yet': 394,
#  'probably': 395,
#  'romney': 396,
#  'taking': 397,
#  'administration': 398,
#  'street': 399,
#  'past': 400,
#  'admits': 401,
#  'hot': 402,
#  'believe': 403,
#  'king': 404,
#  'director': 405,
#  'eating': 406,
#  'pay': 407,
#  'red': 408,
#  'restaurant': 409,
#  'isis': 410,
#  'internet': 411,
#  'guide': 412,
#  'half': 413,
#  "'ve": 414,
#  'list': 415,
#  'justice': 416,
#  'secretary': 417,
#  'beautiful': 418,
#  'tips': 419,
#  '30': 420,
#  'owner': 421,
#  'south': 422,
#  'wins': 423,
#  'dies': 424,
#  'military': 425,
#  'letter': 426,
#  'kill': 427,
#  '50': 428,
#  'excited': 429,
#  'crisis': 430,
#  'officials': 431,
#  'girlfriend': 432,
#  'personal': 433,
#  'small': 434,
#  'young': 435,
#  'talks': 436,
#  'needs': 437,
#  'together': 438,
#  'fbi': 439,
#  'idea': 440,
#  'nuclear': 441,
#  'lost': 442,
#  'questions': 443,
#  "''": 444,
#  'michael': 445,
#  'lot': 446,
#  'set': 447,
#  'service': 448,
#  'system': 449,
#  'latest': 450,
#  'ceo': 451,
#  'ex': 452,
#  'holiday': 453,
#  'congressman': 454,
#  'thought': 455,
#  'march': 456,
#  'wrong': 457,
#  'kid': 458,
#  'someone': 459,
#  'sleep': 460,
#  'warns': 461,
#  'cat': 462,
#  'chris': 463,
#  'birthday': 464,
#  'problem': 465,
#  'move': 466,
#  'assault': 467,
#  'special': 468,
#  'issues': 469,
#  'ask': 470,
#  'birth': 471,
#  'ice': 472,
#  'federal': 473,
#  'un': 474,
#  'following': 475,
#  'celebrates': 476,
#  'abortion': 477,
#  'mark': 478,
#  'florida': 479,
#  'cover': 480,
#  'third': 481,
#  'rise': 482,
#  'nothing': 483,
#  'majority': 484,
#  'bar': 485,
#  'muslim': 486,
#  'giving': 487,
#  'phone': 488,
#  'fun': 489,
#  'al': 490,
#  'wearing': 491,
#  'washington': 492,
#  'moment': 493,
#  'buy': 494,
#  'trip': 495,
#  'knows': 496,
#  'tweets': 497,
#  'less': 498,
#  'series': 499,
#  'box': 500,
#  'hour': 501,
#  'play': 502,
#  'chief': 503,
#  'percent': 504,
#  'late': 505,
#  'fox': 506,
#  'community': 507,
#  'shit': 508,
#  'favorite': 509,
#  'huffpost': 510,
#  'talking': 511,
#  'weekend': 512,
#  'meeting': 513,
#  'online': 514,
#  'break': 515,
#  'syrian': 516,
#  'ted': 517,
#  'hours': 518,
#  '2015': 519,
#  'fashion': 520,
#  'outside': 521,
#  'minute': 522,
#  'using': 523,
#  'message': 524,
#  'career': 525,
#  'become': 526,
#  'adorable': 527,
#  'response': 528,
#  'watching': 529,
#  'months': 530,
#  'stephen': 531,
#  'victims': 532,
#  'syria': 533,
#  'francis': 534,
#  'told': 535,
#  'democratic': 536,
#  'different': 537,
#  'offers': 538,
#  'thinking': 539,
#  'george': 540,
#  'billion': 541,
#  'rules': 542,
#  'read': 543,
#  'cop': 544,
#  'pence': 545,
#  'visit': 546,
#  'hair': 547,
#  'happy': 548,
#  'hope': 549,
#  'least': 550,
#  'union': 551,
#  'bus': 552,
#  'point': 553,
#  'travel': 554,
#  'front': 555,
#  'stars': 556,
#  'anything': 557,
#  'since': 558,
#  'order': 559,
#  'russian': 560,
#  'reasons': 561,
#  'reason': 562,
#  'feel': 563,
#  'k': 564,
#  'protest': 565,
#  'straight': 566,
#  'gift': 567,
#  'crash': 568,
#  'taylor': 569,
#  'senator': 570,
#  'dating': 571,
#  'joe': 572,
#  'millions': 573,
#  'apple': 574,
#  'scott': 575,
#  'david': 576,
#  'accused': 577,
#  'rubio': 578,
#  'trailer': 579,
#  'kind': 580,
#  'names': 581,
#  'well': 582,
#  'lead': 583,
#  'key': 584,
#  'true': 585,
#  'prince': 586,
#  'dinner': 587,
#  'oil': 588,
#  'wars': 589,
#  'powerful': 590,
#  'sick': 591,
#  '100': 592,
#  'c': 593,
#  'hate': 594,
#  'brings': 595,
#  'low': 596,
#  'west': 597,
#  'global': 598,
#  'date': 599,
#  'conversation': 600,
#  'policy': 601,
#  'spends': 602,
#  'learned': 603,
#  'candidates': 604,
#  'artist': 605,
#  'lessons': 606,
#  'voice': 607,
#  'struggling': 608,
#  'discover': 609,
#  'leader': 610,
#  'song': 611,
#  'style': 612,
#  'opens': 613,
#  'far': 614,
#  'general': 615,
#  'schools': 616,
#  'magazine': 617,
#  'amazon': 618,
#  '2017': 619,
#  'j': 620,
#  'vows': 621,
#  'die': 622,
#  "'d": 623,
#  '2014': 624,
#  'drunk': 625,
#  'worried': 626,
#  'members': 627,
#  'workers': 628,
#  'leave': 629,
#  'surprise': 630,
#  'kills': 631,
#  'united': 632,
#  'weird': 633,
#  'nfl': 634,
#  'oscar': 635,
#  'whole': 636,
#  'tom': 637,
#  'employees': 638,
#  'anniversary': 639,
#  'turns': 640,
#  'hit': 641,
#  'waiting': 642,
#  'politics': 643,
#  'fighting': 644,
#  'host': 645,
#  'immigration': 646,
#  'leaders': 647,
#  'tour': 648,
#  'industry': 649,
#  'killing': 650,
#  '40': 651,
#  'prison': 652,
#  'adds': 653,
#  'weight': 654,
#  'near': 655,
#  'reality': 656,
#  'coworker': 657,
#  'act': 658,
#  'fall': 659,
#  'feels': 660,
#  'kardashian': 661,
#  'possible': 662,
#  'test': 663,
#  'relationship': 664,
#  'moving': 665,
#  'important': 666,
#  'iowa': 667,
#  'signs': 668,
#  'stage': 669,
#  'sign': 670,
#  'jr': 671,
#  'stand': 672,
#  'called': 673,
#  'returns': 674,
#  'attacks': 675,
#  'totally': 676,
#  'reportedly': 677,
#  'hits': 678,
#  'massive': 679,
#  'sports': 680,
#  'in': 681,
#  'abuse': 682,
#  'major': 683,
#  'cops': 684,
#  'force': 685,
#  'advice': 686,
#  'breaks': 687,
#  'd': 688,
#  'number': 689,
#  'peace': 690,
#  'bring': 691,
#  'google': 692,
#  'transgender': 693,
#  'mass': 694,
#  'spring': 695,
#  'door': 696,
#  'investigation': 697,
#  'return': 698,
#  'five': 699,
#  'governor': 700,
#  'puts': 701,
#  'executive': 702,
#  'sean': 703,
#  'suspect': 704,
#  'murder': 705,
#  'close': 706,
#  'early': 707,
#  'trans': 708,
#  'suicide': 709,
#  'side': 710,
#  'store': 711,
#  'friday': 712,
#  'huge': 713,
#  'decision': 714,
#  'christian': 715,
#  'light': 716,
#  't': 717,
#  'queer': 718,
#  'jenner': 719,
#  'longer': 720,
#  'paris': 721,
#  'michelle': 722,
#  'worst': 723,
#  'road': 724,
#  'swift': 725,
#  'fuck': 726,
#  'iraq': 727,
#  'carolina': 728,
#  'loses': 729,
#  'all': 730,
#  'netflix': 731,
#  'chinese': 732,
#  'audience': 733,
#  'lgbt': 734,
#  'steve': 735,
#  'wait': 736,
#  'seen': 737,
#  'cut': 738,
#  'ben': 739,
#  'ferguson': 740,
#  'press': 741,
#  'program': 742,
#  'lose': 743,
#  'nasa': 744,
#  'planet': 745,
#  'awards': 746,
#  'whether': 747,
#  'responds': 748,
#  'push': 749,
#  'leaving': 750,
#  'final': 751,
#  'chicago': 752,
#  'park': 753,
#  'poor': 754,
#  '13': 755,
#  'israel': 756,
#  'eyes': 757,
#  'east': 758,
#  'moms': 759,
#  'action': 760,
#  'humans': 761,
#  'jimmy': 762,
#  'mind': 763,
#  'given': 764,
#  'keeps': 765,
#  'shares': 766,
#  'users': 767,
#  'band': 768,
#  'pizza': 769,
#  'biggest': 770,
#  'protesters': 771,
#  'results': 772,
#  'center': 773,
#  'worse': 774,
#  'fear': 775,
#  'almost': 776,
#  'green': 777,
#  'problems': 778,
#  'risk': 779,
#  'asking': 780,
#  'emotional': 781,
#  'building': 782,
#  'male': 783,
#  'hands': 784,
#  'scandal': 785,
#  'bathroom': 786,
#  'allegations': 787,
#  'bowl': 788,
#  'football': 789,
#  'begins': 790,
#  'dance': 791,
#  'planned': 792,
#  'interview': 793,
#  'homeless': 794,
#  'hoping': 795,
#  'hand': 796,
#  'card': 797,
#  'university': 798,
#  'non': 799,
#  'fails': 800,
#  'cool': 801,
#  'voter': 802,
#  'doctor': 803,
#  'spot': 804,
#  'defense': 805,
#  'feeling': 806,
#  'truth': 807,
#  'hall': 808,
#  'starting': 809,
#  'ideas': 810,
#  'refugees': 811,
#  'williams': 812,
#  'check': 813,
#  'ebola': 814,
#  'role': 815,
#  'arrested': 816,
#  'driving': 817,
#  'four': 818,
#  'space': 819,
#  'moore': 820,
#  'science': 821,
#  'easy': 822,
#  'oscars': 823,
#  'crime': 824,
#  'kerry': 825,
#  'picture': 826,
#  'success': 827,
#  'to': 828,
#  'mental': 829,
#  'spend': 830,
#  'board': 831,
#  'harvey': 832,
#  'chance': 833,
#  'words': 834,
#  'on': 835,
#  'suggests': 836,
#  'chicken': 837,
#  'urges': 838,
#  'cnn': 839,
#  'forward': 840,
#  'coffee': 841,
#  'apologizes': 842,
#  'queen': 843,
#  'hotel': 844,
#  'celebrate': 845,
#  'documentary': 846,
#  'supporters': 847,
#  'rest': 848,
#  'remember': 849,
#  'comey': 850,
#  'depression': 851,
#  'halloween': 852,
#  'deadly': 853,
#  'happened': 854,
#  'officer': 855,
#  'louis': 856,
#  'pro': 857,
#  'bear': 858,
#  'plane': 859,
#  'completely': 860,
#  'harassment': 861,
#  'museum': 862,
#  'funding': 863,
#  'website': 864,
#  'pick': 865,
#  'happens': 866,
#  'jones': 867,
#  'throws': 868,
#  'pregnant': 869,
#  'hear': 870,
#  'crowd': 871,
#  'deep': 872,
#  'amazing': 873,
#  'husband': 874,
#  'official': 875,
#  'opening': 876,
#  'reveal': 877,
#  'mean': 878,
#  'simple': 879,
#  'economy': 880,
#  'reminds': 881,
#  '18': 882,
#  'turn': 883,
#  'dreams': 884,
#  'done': 885,
#  'healthy': 886,
#  'senators': 887,
#  'eat': 888,
#  "'it": 889,
#  'review': 890,
#  'boys': 891,
#  'hurricane': 892,
#  '17': 893,
#  'album': 894,
#  'despite': 895,
#  'movies': 896,
#  'blood': 897,
#  'across': 898,
#  'shop': 899,
#  'manager': 900,
#  'desperate': 901,
#  'uses': 902,
#  'apartment': 903,
#  'realizes': 904,
#  'hero': 905,
#  'e': 906,
#  'reform': 907,
#  'holding': 908,
#  'leading': 909,
#  'demand': 910,
#  'try': 911,
#  'explains': 912,
#  'older': 913,
#  'reporter': 914,
#  'fda': 915,
#  'historical': 916,
#  'question': 917,
#  'seeing': 918,
#  'slams': 919,
#  'out': 920,
#  'residents': 921,
#  'movement': 922,
#  'sales': 923,
#  'soon': 924,
#  'short': 925,
#  'episode': 926,
#  'rape': 927,
#  'nearly': 928,
#  'track': 929,
#  'orders': 930,
#  'eric': 931,
#  'color': 932,
#  'lgbtq': 933,
#  'loss': 934,
#  'kelly': 935,
#  'matter': 936,
#  'clean': 937,
#  'worth': 938,
#  'club': 939,
#  'fast': 940,
#  'chair': 941,
#  'repeal': 942,
#  'walking': 943,
#  'justin': 944,
#  'financial': 945,
#  'grandma': 946,
#  'gold': 947,
#  'rich': 948,
#  'among': 949,
#  'playing': 950,
#  'jobs': 951,
#  'likely': 952,
#  'disney': 953,
#  'off': 954,
#  'olympic': 955,
#  "'you": 956,
#  'dying': 957,
#  'anyone': 958,
#  'foreign': 959,
#  'lady': 960,
#  'dress': 961,
#  'colbert': 962,
#  'avoid': 963,
#  'skin': 964,
#  'daily': 965,
#  'sound': 966,
#  '25': 967,
#  'budget': 968,
#  'wishes': 969,
#  'legal': 970,
#  "'star": 971,
#  'said': 972,
#  'culture': 973,
#  'boyfriend': 974,
#  'clearly': 975,
#  'robert': 976,
#  'driver': 977,
#  'primary': 978,
#  'lawsuit': 979,
#  'six': 980,
#  'announce': 981,
#  'spending': 982,
#  'boss': 983,
#  'voting': 984,
#  'miss': 985,
#  'steps': 986,
#  'address': 987,
#  'prevent': 988,
#  'receives': 989,
#  'mccain': 990,
#  'jeff': 991,
#  'teens': 992,
#  'killer': 993,
#  'asked': 994,
#  'families': 995,
#  'hell': 996,
#  'jesus': 997,
#  'sad': 998,
#  'quietly': 999,
#  'telling': 1000,
#  ...}

# %% [markdown]
# ## Padding

# %%
max_length = 100 #max length of a sentence can be 100, if not specified'
#then the length of the longest sentence is sent
trunc_type = 'post' #after a sentence,words are truncated
padding_type = 'post'

# %%
training_sequences = tokenizer.texts_to_sequences(train_sen)

training_padded = pad_sequences(training_sequences, maxlen = max_length, padding=padding_type, truncating = trunc_type)

testing_sequences = tokenizer.texts_to_sequences(test_sen)

testing_padded = pad_sequences(testing_sequences, maxlen=max_length,padding=padding_type,truncating = trunc_type)#padding 
#is done to fill the empty spaces.

# %%
embedding_dim = 16 # embedding determine the context of the text.
model = tf.keras.Sequential([tf.keras.layers.Embedding(vocab_size,embedding_dim, input_length = max_length),
# dim determines dimention.
                             
tf.keras.layers.GlobalAveragePooling1D(),
                            
tf.keras.layers.Dense(24, activation='relu'), 
tf.keras.layers.Dense(1, activation='sigmoid')]) 

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy']) 

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 100, 16)           160000
#
#  global_average_pooling1d (  (None, 16)                0
#  GlobalAveragePooling1D)
#
#  dense (Dense)               (None, 24)                408
#
#  dense_1 (Dense)             (None, 1)                 25
#
# =================================================================
# Total params: 160433 (626.69 KB)
# Trainable params: 160433 (626.69 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
training_padded = np.array(training_padded)
training_labels = np.array(train_label)
testing_padded = np.array(testing_padded)
testing_labels = np.array(test_label)
#converting the list to array for tensorflow

# %%
#training the model...finally ghar ja sakte hai 

num_epochs = 30
history = model.fit(training_padded,training_labels,epochs = num_epochs, validation_data = (testing_padded, testing_labels), verbose = 2)
# Out:
# Epoch 1/30
# 626/626 - 5s - loss: 0.6817 - accuracy: 0.5602 - val_loss: 0.6653 - val_accuracy: 0.5645 - 5s/epoch - 8ms/step
# Epoch 2/30
# 626/626 - 3s - loss: 0.5887 - accuracy: 0.7051 - val_loss: 0.5186 - val_accuracy: 0.7673 - 3s/epoch - 5ms/step
# Epoch 3/30
# 626/626 - 3s - loss: 0.4314 - accuracy: 0.8207 - val_loss: 0.4491 - val_accuracy: 0.7984 - 3s/epoch - 5ms/step
# Epoch 4/30
# 626/626 - 3s - loss: 0.3476 - accuracy: 0.8564 - val_loss: 0.4286 - val_accuracy: 0.8049 - 3s/epoch - 5ms/step
# Epoch 5/30
# 626/626 - 3s - loss: 0.2984 - accuracy: 0.8800 - val_loss: 0.4232 - val_accuracy: 0.8125 - 3s/epoch - 5ms/step
# Epoch 6/30
# 626/626 - 3s - loss: 0.2661 - accuracy: 0.8916 - val_loss: 0.4293 - val_accuracy: 0.8117 - 3s/epoch - 5ms/step
# Epoch 7/30
# 626/626 - 3s - loss: 0.2402 - accuracy: 0.9031 - val_loss: 0.4402 - val_accuracy: 0.8096 - 3s/epoch - 5ms/step
# Epoch 8/30
# 626/626 - 3s - loss: 0.2207 - accuracy: 0.9113 - val_loss: 0.4743 - val_accuracy: 0.8041 - 3s/epoch - 5ms/step
# Epoch 9/30
# 626/626 - 3s - loss: 0.2030 - accuracy: 0.9217 - val_loss: 0.4748 - val_accuracy: 0.8071 - 3s/epoch - 5ms/step
# Epoch 10/30
# 626/626 - 3s - loss: 0.1881 - accuracy: 0.9265 - val_loss: 0.4915 - val_accuracy: 0.8038 - 3s/epoch - 5ms/step
# Epoch 11/30
# 626/626 - 3s - loss: 0.1755 - accuracy: 0.9314 - val_loss: 0.5130 - val_accuracy: 0.7996 - 3s/epoch - 5ms/step
# Epoch 12/30
# 626/626 - 3s - loss: 0.1640 - accuracy: 0.9374 - val_loss: 0.5677 - val_accuracy: 0.7992 - 3s/epoch - 5ms/step
# Epoch 13/30
# 626/626 - 3s - loss: 0.1543 - accuracy: 0.9426 - val_loss: 0.5605 - val_accuracy: 0.7972 - 3s/epoch - 5ms/step
# Epoch 14/30
# 626/626 - 3s - loss: 0.1439 - accuracy: 0.9455 - val_loss: 0.5971 - val_accuracy: 0.7966 - 3s/epoch - 5ms/step
# Epoch 15/30
# 626/626 - 3s - loss: 0.1361 - accuracy: 0.9486 - val_loss: 0.6144 - val_accuracy: 0.7909 - 3s/epoch - 5ms/step
# Epoch 16/30
# 626/626 - 3s - loss: 0.1278 - accuracy: 0.9535 - val_loss: 0.6413 - val_accuracy: 0.7887 - 3s/epoch - 5ms/step
# Epoch 17/30
# 626/626 - 3s - loss: 0.1218 - accuracy: 0.9555 - val_loss: 0.6910 - val_accuracy: 0.7929 - 3s/epoch - 5ms/step
# Epoch 18/30
# 626/626 - 3s - loss: 0.1158 - accuracy: 0.9590 - val_loss: 0.7095 - val_accuracy: 0.7900 - 3s/epoch - 5ms/step
# Epoch 19/30
# 626/626 - 3s - loss: 0.1099 - accuracy: 0.9602 - val_loss: 0.7354 - val_accuracy: 0.7884 - 3s/epoch - 5ms/step
# Epoch 20/30
# 626/626 - 4s - loss: 0.1029 - accuracy: 0.9640 - val_loss: 0.7606 - val_accuracy: 0.7813 - 4s/epoch - 6ms/step
# Epoch 21/30
# 626/626 - 3s - loss: 0.0969 - accuracy: 0.9659 - val_loss: 0.7949 - val_accuracy: 0.7834 - 3s/epoch - 5ms/step
# Epoch 22/30
# 626/626 - 3s - loss: 0.0933 - accuracy: 0.9687 - val_loss: 0.8347 - val_accuracy: 0.7866 - 3s/epoch - 5ms/step
# Epoch 23/30
# 626/626 - 3s - loss: 0.0899 - accuracy: 0.9689 - val_loss: 0.9441 - val_accuracy: 0.7840 - 3s/epoch - 6ms/step
# Epoch 24/30
# 626/626 - 3s - loss: 0.0857 - accuracy: 0.9714 - val_loss: 0.8976 - val_accuracy: 0.7737 - 3s/epoch - 5ms/step
# Epoch 25/30
# 626/626 - 3s - loss: 0.0801 - accuracy: 0.9737 - val_loss: 0.9286 - val_accuracy: 0.7762 - 3s/epoch - 6ms/step
# Epoch 26/30
# 626/626 - 3s - loss: 0.0820 - accuracy: 0.9707 - val_loss: 0.9646 - val_accuracy: 0.7715 - 3s/epoch - 5ms/step
# Epoch 27/30
# 626/626 - 3s - loss: 0.0743 - accuracy: 0.9749 - val_loss: 1.0106 - val_accuracy: 0.7815 - 3s/epoch - 5ms/step
# Epoch 28/30
# 626/626 - 3s - loss: 0.0715 - accuracy: 0.9754 - val_loss: 1.0545 - val_accuracy: 0.7816 - 3s/epoch - 5ms/step
# Epoch 29/30
# 626/626 - 3s - loss: 0.0679 - accuracy: 0.9764 - val_loss: 1.0708 - val_accuracy: 0.7771 - 3s/epoch - 5ms/step
# Epoch 30/30
# 626/626 - 3s - loss: 0.0641 - accuracy: 0.9793 - val_loss: 1.1076 - val_accuracy: 0.7756 - 3s/epoch - 5ms/step

# %%
sen = ["Coworkers at bathroom sink locked in tense standoff over is going to wash hands longer",
      "The covid cases are rising"]
seq = tokenizer.texts_to_sequences(sen)
padded = pad_sequences(seq,maxlen=max_length,padding = padding_type,truncating=trunc_type)
print(model.predict(padded))
# Out:
# 1/1 [==============================] - 0s 193ms/step
# [[0.99998635]
#  [0.01638081]]
